# %% [markdown]
# # Correlation Coefficients

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
raw_data = pd.read_csv('final_data.csv')
display(raw_data)
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 174  Venezuela (Bolivarian Republic of)       SouthAmerica
# 175                            Viet Nam  South-easternAsia
# 176                               Yemen        WesternAsia
# 177                              Zambia      EasternAfrica
# 178                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %%
print(raw_data.corr().shape)
raw_data.corr()
# TODO: Visualisation for the correlation matrix
# Out:
# (38, 38)
#                                                     Surface area (km2)  \
# Surface area (km2)                                            1.000000
# Population in thousands (2017)                                0.445770
# Population density (per km2, 2017)                           -0.078697
# Sex ratio (m per 100 f, 2017)                                -0.055515
# GDP: Gross domestic product (million current US$)             0.550805
# GDP growth rate (annual %, const. 2005 prices)               -0.075240
# GDP per capita (current US$)                                  0.097028
# Economy: Agriculture (% of GVA)                              -0.097314
# Economy: Industry (% of GVA)                                  0.068580
# Economy: Services and other activity (% of GVA)               0.024878
# Employment: Agriculture (% of employed)                      -0.063487
# Employment: Industry (% of employed)                          0.071846
# ...
