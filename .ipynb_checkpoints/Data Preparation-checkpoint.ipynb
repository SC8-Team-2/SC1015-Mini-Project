# %%
import pandas as pd
import numpy as np

# Import applications dataset
application_record = pd.read_csv("data/application_record.csv")
application_record.shape
# Out:
# (438557, 18)

# %%
# Remove Duplicates
application_record.drop_duplicates(subset ="ID", keep = False, inplace = True)

# %%
# Remove Y with 1 and N with 0
application_record['FLAG_OWN_CAR'] = np.where(application_record['FLAG_OWN_CAR'].eq('Y', 'N'), 1, 0)
application_record['FLAG_OWN_REALTY'] = np.where(application_record['FLAG_OWN_REALTY'].eq('Y', 'N'), 1, 0)

# %%
# Calculate age and working years
application_record['APPLICANT_AGE'] = round(-application_record['DAYS_BIRTH'] / 365)
application_record['YEARS_WORKING'] = round(-application_record['DAYS_EMPLOYED'] / 365)

# %%
# Remove applcations < 21 years old
application_record = application_record[application_record['APPLICANT_AGE'] >= 21]  

# Remove rows with null columns
application_record = application_record.dropna()

# %%
# Import credit record dataset
credit_record = pd.read_csv("data/credit_record.csv")
credit_record.shape
# Out:
# (1048575, 3)

# %%
mapz = {
    'C': 'Good Debt', # Loan paid on time
    'X': 'Good Debt', # No loan for the month
    '0': 'Good Debt', # Loan 1-29 days overdue
    '1': 'Bad Debt', # Loan 30-59 days overdue
    '2': 'Bad Debt', # Loan 60-89 days overdue
    '3': 'Bad Debt', # Loan 90-119 days overdue
    '4': 'Bad Debt', # Loan 120-149 days overdue
    '5': 'Bad Debt', # Loan > 150 days overdue
}
credit_record['STATUS_2'] = credit_record['STATUS'].map(mapz)

credit_record['TOTAL_GOOD_DEBT'] = np.where(credit_record['STATUS_2'].eq('Good Debt', 'Bad Debt'), 1, 0)
credit_record['TOTAL_BAD_DEBT'] = np.where(credit_record['STATUS_2'].eq('Good Debt', 'Bad Debt'), 0, 1)

df2 = credit_record.groupby('ID').sum()

df2['STATUS'] = np.where(df2['TOTAL_GOOD_DEBT'] >= df2['TOTAL_BAD_DEBT'], 1, 0)
df2 = df2.drop(columns=['MONTHS_BALANCE'])

df2['GOOD_PERCENT'] = np.where(df2['TOTAL_BAD_DEBT']!= 0, df2['TOTAL_GOOD_DEBT']/(df2['TOTAL_GOOD_DEBT']+df2['TOTAL_BAD_DEBT']), 1)


# Remove empty debt
df2 = df2.dropna()
df2.head()
# Out:
#          TOTAL_GOOD_DEBT  TOTAL_BAD_DEBT  STATUS  GOOD_PERCENT
# ID
# 5001711                4               0       1           1.0
# 5001712               19               0       1           1.0
# 5001713               22               0       1           1.0
# 5001714               15               0       1           1.0
# 5001715               60               0       1           1.0

# %%
new_df = pd.merge(application_record, df2, on="ID")
new_df = new_df.drop(columns=['DAYS_BIRTH','DAYS_EMPLOYED'])
new_df.head()
# Out:
#         ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008806           M             1                1             0
# 1  5008808           F             0                1             0
# 2  5008809           F             0                1             0
# 3  5008810           F             0                1             0
# 4  5008811           F             0                1             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          112500.0               Working  Secondary / secondary special
# 1          270000.0  Commercial associate  Secondary / secondary special
# 2          270000.0  Commercial associate  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  ...  FLAG_PHONE  FLAG_EMAIL  \
# 0               Married  House / apartment  ...           0           0
# 1  Single / not married  House / apartment  ...           1           1
# 2  Single / not married  House / apartment  ...           1           1
# 3  Single / not married  House / apartment  ...           1           1
# 4  Single / not married  House / apartment  ...           1           1
#
#    OCCUPATION_TYPE  CNT_FAM_MEMBERS APPLICANT_AGE  YEARS_WORKING  \
# 0   Security staff              2.0          59.0            3.0
# 1      Sales staff              1.0          52.0            8.0
# 2      Sales staff              1.0          52.0            8.0
# 3      Sales staff              1.0          52.0            8.0
# 4      Sales staff              1.0          52.0            8.0
#
#    TOTAL_GOOD_DEBT  TOTAL_BAD_DEBT  STATUS  GOOD_PERCENT
# 0               30               0       1           1.0
# 1                5               0       1           1.0
# 2                5               0       1           1.0
# 3               27               0       1           1.0
# 4               39               0       1           1.0
#
# [5 rows x 22 columns]

# %%
new_df.to_csv('data/processed_data.csv', index=False)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25134 entries, 0 to 25133
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   25134 non-null  int64
#  1   CODE_GENDER          25134 non-null  object
#  2   FLAG_OWN_CAR         25134 non-null  int32
#  3   FLAG_OWN_REALTY      25134 non-null  int32
#  4   CNT_CHILDREN         25134 non-null  int64
#  5   AMT_INCOME_TOTAL     25134 non-null  float64
#  6   NAME_INCOME_TYPE     25134 non-null  object
#  7   NAME_EDUCATION_TYPE  25134 non-null  object
#  8   NAME_FAMILY_STATUS   25134 non-null  object
#  9   NAME_HOUSING_TYPE    25134 non-null  object
#  10  FLAG_MOBIL           25134 non-null  int64
#  11  FLAG_WORK_PHONE      25134 non-null  int64
#  12  FLAG_PHONE           25134 non-null  int64
#  13  FLAG_EMAIL           25134 non-null  int64
#  14  OCCUPATION_TYPE      25134 non-null  object
#  15  CNT_FAM_MEMBERS      25134 non-null  float64
#  16  APPLICANT_AGE        25134 non-null  float64
#  17  YEARS_WORKING        25134 non-null  float64
#  18  TOTAL_GOOD_DEBT      25134 non-null  int32
#  19  TOTAL_BAD_DEBT       25134 non-null  int32
#  20  STATUS               25134 non-null  int32
#  21  GOOD_PERCENT         25134 non-null  float64
# dtypes: float64(5), int32(5), int64(6), object(6)
# memory usage: 3.9+ MB

# %%
#finding best predictors for variables
countY, countX = new_df.STATUS.value_counts()
print("Ratio of classes is Y : N = ", countY, ":", countX)
# Out:
# Ratio of classes is Y : N =  25048 : 86

# %%
new_df.corr()
# Out:
#                         ID  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# ID                1.000000     -0.025261        -0.086287      0.031461
# FLAG_OWN_CAR     -0.025261      1.000000         0.005388      0.068730
# FLAG_OWN_REALTY  -0.086287      0.005388         1.000000      0.022148
# CNT_CHILDREN      0.031461      0.068730         0.022148      1.000000
# AMT_INCOME_TOTAL -0.019295      0.197636         0.034543     -0.015081
# FLAG_MOBIL             NaN           NaN              NaN           NaN
# FLAG_WORK_PHONE   0.087463     -0.023226        -0.209502     -0.009954
# FLAG_PHONE        0.013311     -0.024812        -0.063936     -0.019342
# FLAG_EMAIL       -0.062874      0.000390         0.061203     -0.015478
# CNT_FAM_MEMBERS   0.024103      0.113174         0.020086      0.902228
# APPLICANT_AGE    -0.037309     -0.072226         0.091309     -0.255850
# YEARS_WORKING    -0.022213     -0.070485         0.009097     -0.065113
# TOTAL_GOOD_DEBT   0.011371      0.035580        -0.035890     -0.010484
# TOTAL_BAD_DEBT    0.021188      0.000038        -0.018317      0.000903
# STATUS           -0.014278     -0.000025         0.003331      0.006972
# GOOD_PERCENT     -0.012531      0.012059         0.015775      0.005090
#
#                   AMT_INCOME_TOTAL  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# ID                       -0.019295         NaN         0.087463    0.013311
# FLAG_OWN_CAR              0.197636         NaN        -0.023226   -0.024812
# FLAG_OWN_REALTY           0.034543         NaN        -0.209502   -0.063936
# CNT_CHILDREN             -0.015081         NaN        -0.009954   -0.019342
# AMT_INCOME_TOTAL          1.000000         NaN        -0.090386    0.010771
# FLAG_MOBIL                     NaN         NaN              NaN         NaN
# FLAG_WORK_PHONE          -0.090386         NaN         1.000000    0.369615
# FLAG_PHONE                0.010771         NaN         0.369615    1.000000
# FLAG_EMAIL                0.076037         NaN        -0.067241    0.009078
# CNT_FAM_MEMBERS          -0.025811         NaN         0.008216   -0.007568
# APPLICANT_AGE             0.058034         NaN        -0.038697    0.026245
# YEARS_WORKING             0.020723         NaN         0.008254    0.041822
# TOTAL_GOOD_DEBT           0.030104         NaN         0.024643    0.018477
# TOTAL_BAD_DEBT            0.015125         NaN         0.007109    0.009298
# STATUS                   -0.003125         NaN         0.006949    0.000270
# GOOD_PERCENT             -0.012275         NaN         0.002614   -0.000842
#
#                   FLAG_EMAIL  CNT_FAM_MEMBERS  APPLICANT_AGE  YEARS_WORKING  \
# ID                 -0.062874         0.024103      -0.037309      -0.022213
# FLAG_OWN_CAR        0.000390         0.113174      -0.072226      -0.070485
# FLAG_OWN_REALTY     0.061203         0.020086       0.091309       0.009097
# CNT_CHILDREN       -0.015478         0.902228      -0.255850      -0.065113
# AMT_INCOME_TOTAL    0.076037        -0.025811       0.058034       0.020723
# FLAG_MOBIL               NaN              NaN            NaN            NaN
# FLAG_WORK_PHONE    -0.067241         0.008216      -0.038697       0.008254
# FLAG_PHONE          0.009078        -0.007568       0.026245       0.041822
# FLAG_EMAIL          1.000000        -0.009906      -0.061468      -0.039756
# CNT_FAM_MEMBERS    -0.009906         1.000000      -0.212130      -0.048740
# APPLICANT_AGE      -0.061468        -0.212130       1.000000       0.342355
# YEARS_WORKING      -0.039756        -0.048740       0.342355       1.000000
# TOTAL_GOOD_DEBT    -0.000025         0.013928       0.091278       0.087485
# TOTAL_BAD_DEBT      0.003366        -0.001250      -0.007078      -0.017071
# STATUS             -0.009835         0.008118       0.009274       0.020773
# GOOD_PERCENT       -0.011039         0.007692       0.025020       0.021921
#
#                   TOTAL_GOOD_DEBT  TOTAL_BAD_DEBT    STATUS  GOOD_PERCENT
# ID                       0.011371        0.021188 -0.014278     -0.012531
# FLAG_OWN_CAR             0.035580        0.000038 -0.000025      0.012059
# FLAG_OWN_REALTY         -0.035890       -0.018317  0.003331      0.015775
# CNT_CHILDREN            -0.010484        0.000903  0.006972      0.005090
# AMT_INCOME_TOTAL         0.030104        0.015125 -0.003125     -0.012275
# FLAG_MOBIL                    NaN             NaN       NaN           NaN
# FLAG_WORK_PHONE          0.024643        0.007109  0.006949      0.002614
# FLAG_PHONE               0.018477        0.009298  0.000270     -0.000842
# FLAG_EMAIL              -0.000025        0.003366 -0.009835     -0.011039
# CNT_FAM_MEMBERS          0.013928       -0.001250  0.008118      0.007692
# APPLICANT_AGE            0.091278       -0.007078  0.009274      0.025020
# YEARS_WORKING            0.087485       -0.017071  0.020773      0.021921
# TOTAL_GOOD_DEBT          1.000000        0.024339  0.059876      0.101051
# TOTAL_BAD_DEBT           0.024339        1.000000 -0.495328     -0.777747
# STATUS                   0.059876       -0.495328  1.000000      0.595315
# GOOD_PERCENT             0.101051       -0.777747  0.595315      1.000000

# %%
#see which categorial numeric variables are good
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

def varacc(a,b):
    # Predict the Response corresponding to Predictors
    
    # Extract Response and Predictors
    y = pd.DataFrame(new_df[a])
    X = pd.DataFrame(new_df[b])

# Split the Dataset into Train and Test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# Decision Tree using Train Data
    dectree = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
    dectree.fit(X_train, y_train)                    # train the decision tree model
    y_train_pred = dectree.predict(X_train)
    print("Train Data for " +  a)
    print("Accuracy  :\t", dectree.score(X_train, y_train))
    print()
    return 

varacc('FLAG_OWN_CAR','STATUS')
varacc('FLAG_OWN_REALTY','STATUS')
varacc('CNT_CHILDREN','STATUS')
varacc('FLAG_WORK_PHONE','STATUS')
varacc('FLAG_PHONE','STATUS')
varacc('FLAG_EMAIL','STATUS')
varacc('CNT_FAM_MEMBERS','STATUS')
varacc('APPLICANT_AGE','STATUS')
varacc('YEARS_WORKING','STATUS')
#varacc('AMT_INCOME_TOTAL','STATUS') 
#varacc('GOOD_PERCENT','STATUS')
#varacc('CNT_FAM_MEMBERS','STATUS')
# Out:
# Train Data for FLAG_OWN_CAR
# Accuracy  :	 0.584075197692346
#
# Train Data for FLAG_OWN_REALTY
# Accuracy  :	 0.6526085442880589
#
# Train Data for CNT_CHILDREN
# Accuracy  :	 0.6330631123489332
#
# Train Data for FLAG_WORK_PHONE
# Accuracy  :	 0.7251703386880191
#
# Train Data for FLAG_PHONE
# Accuracy  :	 0.7086089421594469
#
# Train Data for FLAG_EMAIL
# Accuracy  :	 0.8980454568060874
#
# Train Data for CNT_FAM_MEMBERS
# Accuracy  :	 0.5037051773014373
#
# Train Data for APPLICANT_AGE
# Accuracy  :	 0.04003580842492664
#
# Train Data for YEARS_WORKING
# Accuracy  :	 0.10439150544586462

# %%
numvar = newdf.select_dtypes(include == )

# %%
import matplotlib.pyplot as plt 
import seaborn as sb
sb.set()

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix


y = pd.DataFrame(new_df['STATUS'])
x =pd.DataFrame(new_df[["AMT_INCOME_TOTAL","APPLICANT_AGE","YEARS_WORKING","CNT_FAM_MEMBERS"]])
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

dectree = DecisionTreeClassifier(max_depth = 4) # create the decision tree object
dectree.fit(X_train, y_train)                    # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.996551724137931
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9968178202068417

# %%
# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9965075154730327
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9972155926809865
# <AxesSubplot:>

# %%
from sklearn.tree import plot_tree

f = plt.figure(figsize=(12,12))
plot_tree(dectree, filled=True, rounded=True, 
          feature_names=X_train.columns, 
          class_names=["Bad","Good"])
# Out:
# [Text(334.8, 543.6, 'YEARS_WORKING <= 2.5\ngini = 0.007\nsamples = 18850\nvalue = [66, 18784]\nclass = Good'),
#  Text(167.4, 326.16, 'AMT_INCOME_TOTAL <= 447750.0\ngini = 0.015\nsamples = 4349\nvalue = [32, 4317]\nclass = Good'),
#  Text(83.7, 108.72000000000003, 'gini = 0.013\nsamples = 4274\nvalue = [27, 4247]\nclass = Good'),
#  Text(251.10000000000002, 108.72000000000003, 'gini = 0.124\nsamples = 75\nvalue = [5, 70]\nclass = Good'),
#  Text(502.20000000000005, 326.16, 'AMT_INCOME_TOTAL <= 855000.0\ngini = 0.005\nsamples = 14501\nvalue = [34, 14467]\nclass = Good'),
#  Text(418.5, 108.72000000000003, 'gini = 0.005\nsamples = 14454\nvalue = [33, 14421]\nclass = Good'),
#  Text(585.9, 108.72000000000003, 'gini = 0.042\nsamples = 47\nvalue = [1, 46]\nclass = Good')]
