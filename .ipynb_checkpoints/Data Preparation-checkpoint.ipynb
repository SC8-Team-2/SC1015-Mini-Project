# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Preparation of Suicide Rates Data

# %%
csv_data = pd.read_csv("final_table.csv")
csv_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15248/635262923.py in <module>
# ----> 1 csv_data = pd.read_csv("final_table.csv")
#       2 csv_data
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'final_table.csv'

# %% [markdown]
# ## Year distribution

# %%
years = csv_data['year']
years.value_counts()

# %% [markdown]
# ## Filtering rows from year 2014

# %%
csv_data = csv_data[csv_data['year'] == 2014]
csv_data

# %% [markdown]
# ## Filtering country and suicide columns

# %%
focus = csv_data[['country', 'suicides/100k pop']]
focus

# %% [markdown]
# ## Table of Country : Suicides per 100k population

# %%
aggregation_functions = {'suicides/100k pop': 'sum'}
final = focus.groupby(focus['country']).aggregate(aggregation_functions)

# %%
final.describe()

# %% [markdown]
# ### Alphabetical Order

# %%
final

# %% [markdown]
# ### Descending Order

# %%
final.sort_values(by = ['suicides/100k pop'], ascending = False)

# %% [markdown]
# # Preparation of Country Statistics Data

# %%
country_stats = pd.read_csv('country_profile_variables.csv')
print(country_stats.shape)
display(country_stats)
# Out:
# (229, 50)
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# 1                              2930                               106.9
# 2                             41318                                17.3
# 3                                56                               278.2
# 4                                77                               163.8
# ..                              ...                                 ...
# 224                              12                                84.1
# 225                             553                                 2.1
# 226                           28250                                53.5
# 227                           17094                                23.0
# 228                           16530                                42.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 0                            106.3
# 1                            101.9
# 2                            102.0
# 3                            103.6
# 4                            102.3
# ..                             ...
# 224                           93.4
# 225                          110.1
# 226                          102.1
# 227                           98.5
# 228                           95.0
#
#      GDP: Gross domestic product (million current US$)  \
# 0                                                20270
# 1                                                11541
# 2                                               164779
# 3                                                  -99
# 4                                                 2812
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                              29688
# 227                                              21255
# 228                                              13893
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 0                                             -2.4
# 1                                              2.6
# 2                                              3.8
# 3                                              -99
# 4                                              0.8
# ..                                             ...
# 224                                            -99
# 225                                            -99
# 226                                          -28.1
# 227                                            2.9
# 228                                            1.1
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 0                           623.2                            23.3  ...
# 1                          3984.2                            22.4  ...
# 2                          4154.1                            12.2  ...
# 3                           -99.0                             -99  ...
# 4                         39896.4                             0.5  ...
# ..                            ...                             ...  ...
# 224                         -99.0                             -99  ...
# 225                         -99.0                             -99  ...
# 226                        1106.4                            14.7  ...
# 227                        1311.1                             8.2  ...
# 228                         890.4                            13.0  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                  -99
# 4                                                 96.9
# ..                                                 ...
# 224                                                9.0
# 225                                                -99
# 226                                               25.1
# 227                                               21.0
# 228                                               16.4
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 0                                                   42
# 1                                                  130
# 2                                                  135
# 3                                                   92
# 4                                                   13
# ..                                                 ...
# 224                                                 89
# 225                                                 49
# 226                                                298
# 227                                                 88
# 228                                                 89
#
#     Threatened species (number) Forested area (% of land area)  \
# 0                           2.1                        9.8/0.3
# 1                          28.2                        5.7/2.0
# 2                           0.8                      145.4/3.7
# 3                          87.9                            -99
# 4                          34.0                        0.5/6.4
# ..                          ...                            ...
# 224                        41.6                       ~0.0/1.6
# 225                         2.7                            -99
# 226                         1.0                       22.7/0.9
# 227                        65.6                        4.5/0.3
# 228                        37.2                       12.0/0.8
#
#     CO2 emission estimates (million tons/tons per capita)  \
# 0                                                   63
# 1                                                   84
# 2                                                 5900
# 3                                                  -99
# 4                                                    1
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                                668
# 227                                                374
# 228                                                482
#
#     Energy production, primary (Petajoules)  \
# 0                                         5
# 1                                        36
# 2                                        55
# 3                                       -99
# 4                                       119
# ..                                      ...
# 224                                      26
# 225                                     -99
# 226                                      12
# 227                                      26
# 228                                      30
#
#     Energy supply per capita (Gigajoules)  \
# 0                               78.2/47.0
# 1                               94.9/95.2
# 2                               84.3/81.8
# 3                             100.0/100.0
# 4                             100.0/100.0
# ..                                    ...
# 224                                   -99
# 225                                   -99
# 226                             72.0/46.5
# 227                             85.6/51.3
# 228                             97.0/67.3
#
#      Pop. using improved drinking water (urban/rural, %)  \
# 0                                            45.1/27.0
# 1                                            95.5/90.2
# 2                                            89.8/82.2
# 3                                            62.5/62.5
# 4                                          100.0/100.0
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                          92.5/34.1
# 227                                          55.6/35.7
# 228                                          49.3/30.8
#
#      Pop. using improved sanitation facilities (urban/rural, %)  \
# 0                                                21.43
# 1                                                 2.96
# 2                                                 0.05
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                               2.99
# 227                                               3.96
# 228                                               6.00
#
#     Net Official Development Assist. received (% of GNI)
# 0                                                  -99
# 1                                                  -99
# 2                                                  -99
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                                -99
# 227                                                -99
# 228                                                -99
#
# [229 rows x 50 columns]

# %% [markdown]
# ## List of Variables

# %%
for col in country_stats.columns:
    print(col)
# Out:
# country
# Region
# Surface area (km2)
# Population in thousands (2017)
# Population density (per km2, 2017)
# Sex ratio (m per 100 f, 2017)
# GDP: Gross domestic product (million current US$)
# GDP growth rate (annual %, const. 2005 prices)
# GDP per capita (current US$)
# Economy: Agriculture (% of GVA)
# Economy: Industry (% of GVA)
# Economy: Services and other activity (% of GVA)
# Employment: Agriculture (% of employed)
# Employment: Industry (% of employed)
# Employment: Services (% of employed)
# Unemployment (% of labour force)
# Labour force participation (female/male pop. %)
# Agricultural production index (2004-2006=100)
# Food production index (2004-2006=100)
# International trade: Exports (million US$)
# International trade: Imports (million US$)
# International trade: Balance (million US$)
# Balance of payments, current account (million US$)
# Population growth rate (average annual %)
# Urban population (% of total population)
# Urban population growth rate (average annual %)
# Fertility rate, total (live births per woman)
# Life expectancy at birth (females/males, years)
# Population age distribution (0-14 / 60+ years, %)
# International migrant stock (000/% of total pop.)
# Refugees and others of concern to UNHCR (in thousands)
# Infant mortality rate (per 1000 live births
# Health: Total expenditure (% of GDP)
# Health: Physicians (per 1000 pop.)
# Education: Government expenditure (% of GDP)
# Education: Primary gross enrol. ratio (f/m per 100 pop.)
# Education: Secondary gross enrol. ratio (f/m per 100 pop.)
# Education: Tertiary gross enrol. ratio (f/m per 100 pop.)
# Seats held by women in national parliaments %
# Mobile-cellular subscriptions (per 100 inhabitants)
# Mobile-cellular subscriptions (per 100 inhabitants).1
# Individuals using the Internet (per 100 inhabitants)
# Threatened species (number)
# Forested area (% of land area)
# CO2 emission estimates (million tons/tons per capita)
# Energy production, primary (Petajoules)
# Energy supply per capita (Gigajoules)
# Pop. using improved drinking water (urban/rural, %)
# Pop. using improved sanitation facilities (urban/rural, %)
# Net Official Development Assist. received (% of GNI)

# %% [markdown]
# ## Filtering Variables

# %%
# TODO: Decide if we should filter variables now or after calculating correlations
# i think i have to remove columns like: 'Labour force participation (female/male pop. %)' because the values aren't a number
country_stats.drop(columns=['Labour force participation (female/male pop. %)'], inplace=True)
country_stats.drop(columns=['Life expectancy at birth (females/males, years)'], inplace=True)
country_stats.drop(columns=['Population age distribution (0-14 / 60+ years, %)'], inplace=True)
country_stats.drop(columns=['International migrant stock (000/% of total pop.)'], inplace=True)
country_stats.drop(columns=['Education: Primary gross enrol. ratio (f/m per 100 pop.)'], inplace=True)
country_stats.drop(columns=['Education: Secondary gross enrol. ratio (f/m per 100 pop.)'], inplace=True)
country_stats.drop(columns=['Education: Tertiary gross enrol. ratio (f/m per 100 pop.)'], inplace=True)
country_stats.drop(columns=['Energy supply per capita (Gigajoules)'], inplace=True)
country_stats.drop(columns=['Forested area (% of land area)'], inplace=True)
country_stats.drop(columns=['Pop. using improved drinking water (urban/rural, %)'], inplace=True)
country_stats.drop(columns=['Net Official Development Assist. received (% of GNI)'], inplace=True)

display(country_stats)
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# 1                              2930                               106.9
# 2                             41318                                17.3
# 3                                56                               278.2
# 4                                77                               163.8
# ..                              ...                                 ...
# 224                              12                                84.1
# 225                             553                                 2.1
# 226                           28250                                53.5
# 227                           17094                                23.0
# 228                           16530                                42.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 0                            106.3
# 1                            101.9
# 2                            102.0
# 3                            103.6
# 4                            102.3
# ..                             ...
# 224                           93.4
# 225                          110.1
# 226                          102.1
# 227                           98.5
# 228                           95.0
#
#      GDP: Gross domestic product (million current US$)  \
# 0                                                20270
# 1                                                11541
# 2                                               164779
# 3                                                  -99
# 4                                                 2812
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                              29688
# 227                                              21255
# 228                                              13893
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 0                                             -2.4
# 1                                              2.6
# 2                                              3.8
# 3                                              -99
# 4                                              0.8
# ..                                             ...
# 224                                            -99
# 225                                            -99
# 226                                          -28.1
# 227                                            2.9
# 228                                            1.1
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 0                           623.2                            23.3  ...
# 1                          3984.2                            22.4  ...
# 2                          4154.1                            12.2  ...
# 3                           -99.0                             -99  ...
# 4                         39896.4                             0.5  ...
# ..                            ...                             ...  ...
# 224                         -99.0                             -99  ...
# 225                         -99.0                             -99  ...
# 226                        1106.4                            14.7  ...
# 227                        1311.1                             8.2  ...
# 228                         890.4                            13.0  ...
#
#      Health: Physicians (per 1000 pop.)  \
# 0                                   0.3
# 1                                   1.3
# 2                                   ...
# 3                                   -99
# 4                                   3.7
# ..                                  ...
# 224                                 -99
# 225                                 -99
# 226                                 0.3
# 227                                 0.2
# 228                                 0.1
#
#      Education: Government expenditure (% of GDP)  \
# 0                                             3.3
# 1                                             3.5
# 2                                             ...
# 3                                             -99
# 4                                             3.3
# ..                                            ...
# 224                                           -99
# 225                                           -99
# 226                                           ...
# 227                                           ...
# 228                                           8.4
#
#     Seats held by women in national parliaments %  \
# 0                                            27.7
# 1                                            22.9
# 2                                            31.6
# 3                                           -99.0
# 4                                            32.1
# ..                                            ...
# 224                                         -99.0
# 225                                         -99.0
# 226                                           0.0
# 227                                          18.0
# 228                                          32.6
#
#     Mobile-cellular subscriptions (per 100 inhabitants)  \
# 0                                                 61.6
# 1                                                106.4
# 2                                                113.0
# 3                                                  ...
# 4                                                 88.1
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                               68.0
# 227                                               74.5
# 228                                               84.8
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                  -99
# 4                                                 96.9
# ..                                                 ...
# 224                                                9.0
# 225                                                -99
# 226                                               25.1
# 227                                               21.0
# 228                                               16.4
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 0                                                   42
# 1                                                  130
# 2                                                  135
# 3                                                   92
# 4                                                   13
# ..                                                 ...
# 224                                                 89
# 225                                                 49
# 226                                                298
# 227                                                 88
# 228                                                 89
#
#      Threatened species (number)  \
# 0                            2.1
# 1                           28.2
# 2                            0.8
# 3                           87.9
# 4                           34.0
# ..                           ...
# 224                         41.6
# 225                          2.7
# 226                          1.0
# 227                         65.6
# 228                         37.2
#
#      CO2 emission estimates (million tons/tons per capita)  \
# 0                                                   63
# 1                                                   84
# 2                                                 5900
# 3                                                  -99
# 4                                                    1
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                                668
# 227                                                374
# 228                                                482
#
#     Energy production, primary (Petajoules)  \
# 0                                         5
# 1                                        36
# 2                                        55
# 3                                       -99
# 4                                       119
# ..                                      ...
# 224                                      26
# 225                                     -99
# 226                                      12
# 227                                      26
# 228                                      30
#
#     Pop. using improved sanitation facilities (urban/rural, %)
# 0                                                21.43
# 1                                                 2.96
# 2                                                 0.05
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                               2.99
# 227                                               3.96
# 228                                               6.00
#
# [229 rows x 39 columns]

# %% [markdown]
# ## Filtering Countries
# We filtered out the countries from the Country Statistics Data which were not found in Suicide Rates data, and vice versa

# %%
countries_suicide = list(set(focus['country'].values))
countries_stats = list(set(country_stats['country'].values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15248/1845535313.py in <module>
# ----> 1 countries_suicide = list(set(focus['country'].values))
#       2 countries_stats = list(set(country_stats['country'].values))
#
# NameError: name 'focus' is not defined

# %%
for index, row in country_stats.iterrows():
    if row['country'] not in countries_suicide:
        country_stats.drop(index, inplace=True)
print(country_stats.shape)
pd.set_option('display.max_columns', None)
country_stats.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15248/1916714.py in <module>
#       1 for index, row in country_stats.iterrows():
# ----> 2     if row['country'] not in countries_suicide:
#       3         country_stats.drop(index, inplace=True)
#       4 print(country_stats.shape)
#       5 pd.set_option('display.max_columns', None)
#
# NameError: name 'countries_suicide' is not defined

# %%
for index, row in final.iterrows():
    if index not in countries_stats:
        final.drop(index, inplace=True)
print(final.shape)
final.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15248/1207771402.py in <module>
# ----> 1 for index, row in final.iterrows():
#       2     if index not in countries_stats:
#       3         final.drop(index, inplace=True)
#       4 print(final.shape)
#       5 final.head()
#
# NameError: name 'final' is not defined

# %% [markdown]
# ## Cleaning Data
# Correction of invalid data and data types

# %% [markdown]
# ### Correction of Invalid Data

# %%
country_stats.loc[country_stats['country'] == 'Singapore', 'Economy: Agriculture (% of GVA)'] = 0.0
country_stats.loc[country_stats['country'] == 'Singapore', 'Refugees and others of concern to UNHCR (in thousands)'] = 0.0
country_stats.loc[country_stats['country'] == 'Oman', 'Threatened species (number)'] = 0.0
country_stats.replace('...', np.nan, inplace = True)
country_stats.replace(-99, np.nan, inplace = True)
display(country_stats)
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# 1                              2930                               106.9
# 2                             41318                                17.3
# 3                                56                               278.2
# 4                                77                               163.8
# ..                              ...                                 ...
# 224                              12                                84.1
# 225                             553                                 2.1
# 226                           28250                                53.5
# 227                           17094                                23.0
# 228                           16530                                42.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 0                            106.3
# 1                            101.9
# 2                            102.0
# 3                            103.6
# 4                            102.3
# ..                             ...
# 224                           93.4
# 225                          110.1
# 226                          102.1
# 227                           98.5
# 228                           95.0
#
#      GDP: Gross domestic product (million current US$)  \
# 0                                              20270.0
# 1                                              11541.0
# 2                                             164779.0
# 3                                                  NaN
# 4                                               2812.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                            29688.0
# 227                                            21255.0
# 228                                            13893.0
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 0                                             -2.4
# 1                                              2.6
# 2                                              3.8
# 3                                              -99
# 4                                              0.8
# ..                                             ...
# 224                                            -99
# 225                                            -99
# 226                                          -28.1
# 227                                            2.9
# 228                                            1.1
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 0                           623.2                            23.3  ...
# 1                          3984.2                            22.4  ...
# 2                          4154.1                            12.2  ...
# 3                             NaN                             -99  ...
# 4                         39896.4                             0.5  ...
# ..                            ...                             ...  ...
# 224                           NaN                             -99  ...
# 225                           NaN                             -99  ...
# 226                        1106.4                            14.7  ...
# 227                        1311.1                             8.2  ...
# 228                         890.4                            13.0  ...
#
#      Health: Physicians (per 1000 pop.)  \
# 0                                   0.3
# 1                                   1.3
# 2                                   NaN
# 3                                   -99
# 4                                   3.7
# ..                                  ...
# 224                                 -99
# 225                                 -99
# 226                                 0.3
# 227                                 0.2
# 228                                 0.1
#
#      Education: Government expenditure (% of GDP)  \
# 0                                             3.3
# 1                                             3.5
# 2                                             NaN
# 3                                             -99
# 4                                             3.3
# ..                                            ...
# 224                                           -99
# 225                                           -99
# 226                                           NaN
# 227                                           NaN
# 228                                           8.4
#
#     Seats held by women in national parliaments %  \
# 0                                            27.7
# 1                                            22.9
# 2                                            31.6
# 3                                             NaN
# 4                                            32.1
# ..                                            ...
# 224                                           NaN
# 225                                           NaN
# 226                                           0.0
# 227                                          18.0
# 228                                          32.6
#
#     Mobile-cellular subscriptions (per 100 inhabitants)  \
# 0                                                 61.6
# 1                                                106.4
# 2                                                113.0
# 3                                                  NaN
# 4                                                 88.1
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                               68.0
# 227                                               74.5
# 228                                               84.8
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                  -99
# 4                                                 96.9
# ..                                                 ...
# 224                                                9.0
# 225                                                -99
# 226                                               25.1
# 227                                               21.0
# 228                                               16.4
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 0                                                 42.0
# 1                                                130.0
# 2                                                135.0
# 3                                                 92.0
# 4                                                 13.0
# ..                                                 ...
# 224                                               89.0
# 225                                               49.0
# 226                                              298.0
# 227                                               88.0
# 228                                               89.0
#
#      Threatened species (number)  \
# 0                            2.1
# 1                           28.2
# 2                            0.8
# 3                           87.9
# 4                           34.0
# ..                           ...
# 224                         41.6
# 225                          2.7
# 226                          1.0
# 227                         65.6
# 228                         37.2
#
#      CO2 emission estimates (million tons/tons per capita)  \
# 0                                                 63.0
# 1                                                 84.0
# 2                                               5900.0
# 3                                                  NaN
# 4                                                  1.0
# ..                                                 ...
# 224                                                NaN
# 225                                                NaN
# 226                                              668.0
# 227                                              374.0
# 228                                              482.0
#
#     Energy production, primary (Petajoules)  \
# 0                                       5.0
# 1                                      36.0
# 2                                      55.0
# 3                                       NaN
# 4                                     119.0
# ..                                      ...
# 224                                    26.0
# 225                                     NaN
# 226                                    12.0
# 227                                    26.0
# 228                                    30.0
#
#     Pop. using improved sanitation facilities (urban/rural, %)
# 0                                                21.43
# 1                                                 2.96
# 2                                                 0.05
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                               2.99
# 227                                               3.96
# 228                                               6.00
#
# [229 rows x 39 columns]

# %% [markdown]
# ### Correcting Data Types

# %%
for col in list(country_stats.columns.values):
    if col != 'country' and col != 'Region':
        country_stats[col] = country_stats[col].astype(float)
country_stats.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15248/1066063786.py in <module>
#       1 for col in list(country_stats.columns.values):
#       2     if col != 'country' and col != 'Region':
# ----> 3         country_stats[col] = country_stats[col].astype(float)
#       4 country_stats.dtypes
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1199     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1200         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1201         return arr.astype(dtype, copy=True)
#    1202
#    1203     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '~0'

# %% [markdown]
# ## Cleaned Country Statistics Data

# %%
final_stats = pd.DataFrame(country_stats)
final_stats.head()

# %%
final_stats.describe()

# %%
print(final_stats.shape)
