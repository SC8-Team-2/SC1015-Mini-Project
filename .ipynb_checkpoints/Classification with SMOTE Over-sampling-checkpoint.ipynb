# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

from imblearn.over_sampling import SMOTE
from sklearn.cluster import KMeans
from clover.over_sampling import ClusterOverSampler

import matplotlib.pyplot as plt
sb.set()

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

df = pd.read_csv("data/processed_data.csv")

# %% [markdown]
# # Generating Balanced Dataset with Over-sampling

# %%
# Function for calculating ratio of majority and minority class
def ratio(df):
    print(df['STATUS'].value_counts())
    print(df['STATUS'].value_counts(normalize=True))
    sb.catplot(y = "STATUS", data = df, kind = "count")
    print()
 
# Function to calculating metrics of confusionMatrix
def confusionMatrix(matrix, flag):
    #TN FP
    #FN TP
    
    TN = matrix[0][0]
    FP = matrix[0][1]
    FN = matrix[1][0]
    TP = matrix[1][1]
    if flag:
        print("Test Dataset: ")
    else:
        print("Train Dataset: ")
    
    print("True Positive Rate: {:.2f}%".format((TP * 100)/(TP + FN)))
    print("False Positive Rate: {:.2f}%\n".format((FP * 100)/(FP + TN)))
    
    print("True Negative Rate: {:.2f}%".format((TN * 100)/(TN + FP)))
    print("False Negative Rate: {:.2f}%\n".format((FN * 100)/(FN + TP)))
    print()

ratio(df)
# Out:
# 1    25048
# 0       86
# Name: STATUS, dtype: int64
# 1    0.996578
# 0    0.003422
# Name: STATUS, dtype: float64

# %%
non_int = ["ID", "TOTAL_GOOD_DEBT", "TOTAL_BAD_DEBT"]
for col in df:
    if df[col].dtypes == "object":
        non_int.append(col)
new_df = df.drop(columns=non_int)

# %%
# Considering numeric vars only
# Over-sampling (using SMOTE - Synthetic Minority Over-sampling TEchnique)

# Dictionary to store top 5 variables - {score : var_name}
top = {}

y = pd.DataFrame(new_df["STATUS"])
for col in new_df:
    if col != 'STATUS' and col != 'GOOD_PERCENT' and col != 'FLAG_EMAIL':
        X = pd.DataFrame(new_df[col])
        
        # Resampling the minority class. The strategy can be changed as required.
        sm = SMOTE(sampling_strategy='minority', random_state=42)

        # Fit and resample imbalanced data
        X_res, y_res = sm.fit_resample(X, y) # kmeans_smote.fit_resample(X, y)
        print(col)

        # Split the Dataset into Train and Test
        X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.25)

        # Decision Tree using Train Data
        dectree = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
        dectree.fit(X_train, y_train)                    # train the decision tree model
        y_train_pred = dectree.predict(X_train)
        print("Train Data for " +  col)
        score = dectree.score(X_train, y_train)
        print(f'Accuracy  :\t{score}')
        print()
        confusionMatrix(confusion_matrix(y_train1, y_train_pred), 0)
        if len(top) < 3:
            top[score] = col
        elif score > min(top.keys()):
            top.pop(min(top.keys()))
            top[score] = col

print()
print('BEST VARIABLES:')
for key, val in top.items():
    print(f'{val}      \t: {key}')
# Out:
# FLAG_OWN_CAR
# Train Data for FLAG_OWN_CAR
# Accuracy  :	0.5019429362291068
#
# Train Dataset:
# True Positive Rate: 0.00%
# False Positive Rate: 0.00%
#
# True Negative Rate: 100.00%
# False Negative Rate: 100.00%
#
#
# FLAG_OWN_REALTY
# Train Data for FLAG_OWN_REALTY
# Accuracy  :	0.5150644096667731
#
# Train Dataset:
# True Positive Rate: 64.04%
# False Positive Rate: 64.17%
#
# True Negative Rate: 35.83%
# False Negative Rate: 35.96%
#
#
# CNT_CHILDREN
# Train Data for CNT_CHILDREN
# Accuracy  :	0.5389651868412648
#
# Train Dataset:
# True Positive Rate: 8.22%
# False Positive Rate: 8.58%
#
# True Negative Rate: 91.42%
# False Negative Rate: 91.78%
#
#
# AMT_INCOME_TOTAL
# Train Data for AMT_INCOME_TOTAL
# Accuracy  :	0.637336314276589
#
# Train Dataset:
# True Positive Rate: 41.70%
# False Positive Rate: 42.12%
#
# True Negative Rate: 57.88%
# False Negative Rate: 58.30%
#
#
# FLAG_MOBIL
# Train Data for FLAG_MOBIL
# Accuracy  :	0.5011977004152028
#
# Train Dataset:
# True Positive Rate: 0.00%
# False Positive Rate: 0.00%
#
# True Negative Rate: 100.00%
# False Negative Rate: 100.00%
#
#
# FLAG_WORK_PHONE
# Train Data for FLAG_WORK_PHONE
# Accuracy  :	0.5270414138188012
#
# Train Dataset:
# True Positive Rate: 25.05%
# False Positive Rate: 24.62%
#
# True Negative Rate: 75.38%
# False Negative Rate: 74.95%
#
#
# FLAG_PHONE
# Train Data for FLAG_PHONE
# Accuracy  :	0.5015437027573725
#
# Train Dataset:
# True Positive Rate: 29.10%
# False Positive Rate: 29.14%
#
# True Negative Rate: 70.86%
# False Negative Rate: 70.90%
#
#
# CNT_FAM_MEMBERS
# Train Data for CNT_FAM_MEMBERS
# Accuracy  :	0.5607633343979559
#
# Train Dataset:
# True Positive Rate: 56.27%
# False Positive Rate: 56.44%
#
# True Negative Rate: 43.56%
# False Negative Rate: 43.73%
#
#
# APPLICANT_AGE
# Train Data for APPLICANT_AGE
# Accuracy  :	0.6175875652081337
#
# Train Dataset:
# True Positive Rate: 59.75%
# False Positive Rate: 60.14%
#
# True Negative Rate: 39.86%
# False Negative Rate: 40.25%
#
#
# YEARS_WORKING
# Train Data for YEARS_WORKING
# Accuracy  :	0.643324816352603
#
# Train Dataset:
# True Positive Rate: 36.37%
# False Positive Rate: 36.00%
#
# True Negative Rate: 64.00%
# False Negative Rate: 63.63%
#
#
#
# BEST VARIABLES:
# AMT_INCOME_TOTAL      	: 0.637336314276589
# APPLICANT_AGE      	: 0.6175875652081337
# YEARS_WORKING      	: 0.643324816352603

# %% [markdown]
# # Prediction Using Balanced Dataset

# %%
'''Over-sampling'''

y1 = pd.DataFrame(new_df['STATUS'])
print('Before Over-sampling: ')
ratio(y1)

best = top.values()
for col in new_df:
    if col not in best:
        new_df.drop(columns=col, inplace=True)
x1 = pd.DataFrame(new_df)
print(x1.describe())
print()

X_temp, y_temp = sm.fit_resample(x1, y1)
print('After Over-sampling: ')
ratio(y_temp)


'''Prediction'''

X_train1, X_test1, y_train1, y_test1 = train_test_split(X_temp, y_temp, test_size=0.25)

dectree = DecisionTreeClassifier(max_depth = 4) # create the decision tree object
dectree.fit(X_train1, y_train1)                    # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred1 = dectree.predict(X_train1)
y_test_pred1 = dectree.predict(X_test1)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train1, y_train1))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test1, y_test1))
print()
# Out:
# Before Over-sampling:
# 1    25048
# 0       86
# Name: STATUS, dtype: int64
# 1    0.996578
# 0    0.003422
# Name: STATUS, dtype: float64
#
#        AMT_INCOME_TOTAL  APPLICANT_AGE  YEARS_WORKING
# count      2.513400e+04   25134.000000   25134.000000
# mean       1.948339e+05      40.536166       7.204106
# std        1.045110e+05       9.559474       6.414231
# min        2.700000e+04      21.000000       0.000000
# 25%        1.350000e+05      33.000000       3.000000
# 50%        1.800000e+05      40.000000       5.000000
# 75%        2.250000e+05      48.000000      10.000000
# max        1.575000e+06      67.000000      43.000000
#
# After Over-sampling:
# 1    25048
# 0    25048
# Name: STATUS, dtype: int64
# 1    0.5
# 0    0.5
# Name: STATUS, dtype: float64
#
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.6804535292238901
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.6696742254870648

# %%
# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train1, y_train_pred1),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test1, y_test_pred1), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
# Out:
# <AxesSubplot:>

# %%
from sklearn.tree import plot_tree

f = plt.figure(figsize=(12,12), dpi = 300)
plot_tree(dectree, filled=True, rounded=True, 
          feature_names=X_train1.columns, 
          class_names=["Bad","Good"])
# Out:
# [Text(0.5, 0.9, 'YEARS_WORKING <= 4.5\ngini = 0.5\nsamples = 37572\nvalue = [18704, 18868]\nclass = Good'),
#  Text(0.25, 0.7, 'AMT_INCOME_TOTAL <= 405029.5\ngini = 0.476\nsamples = 20571\nvalue = [12546, 8025]\nclass = Bad'),
#  Text(0.125, 0.5, 'AMT_INCOME_TOTAL <= 116991.0\ngini = 0.488\nsamples = 18512\nvalue = [10677, 7835]\nclass = Bad'),
#  Text(0.0625, 0.3, 'APPLICANT_AGE <= 27.5\ngini = 0.395\nsamples = 6217\nvalue = [4535, 1682]\nclass = Bad'),
#  Text(0.03125, 0.1, 'gini = 0.0\nsamples = 227\nvalue = [0, 227]\nclass = Good'),
#  Text(0.09375, 0.1, 'gini = 0.368\nsamples = 5990\nvalue = [4535, 1455]\nclass = Bad'),
#  Text(0.1875, 0.3, 'AMT_INCOME_TOTAL <= 314972.0\ngini = 0.5\nsamples = 12295\nvalue = [6142, 6153]\nclass = Good'),
#  Text(0.15625, 0.1, 'gini = 0.499\nsamples = 11618\nvalue = [6062, 5556]\nclass = Bad'),
#  Text(0.21875, 0.1, 'gini = 0.208\nsamples = 677\nvalue = [80, 597]\nclass = Good'),
#  Text(0.375, 0.5, 'YEARS_WORKING <= 3.5\ngini = 0.168\nsamples = 2059\nvalue = [1869, 190]\nclass = Bad'),
#  Text(0.3125, 0.3, 'APPLICANT_AGE <= 40.5\ngini = 0.128\nsamples = 1986\nvalue = [1850, 136]\nclass = Bad'),
#  Text(0.28125, 0.1, 'gini = 0.068\nsamples = 1720\nvalue = [1659, 61]\nclass = Bad'),
#  Text(0.34375, 0.1, 'gini = 0.405\nsamples = 266\nvalue = [191, 75]\nclass = Bad'),
#  Text(0.4375, 0.3, 'AMT_INCOME_TOTAL <= 447878.5\ngini = 0.385\nsamples = 73\nvalue = [19, 54]\nclass = Good'),
#  Text(0.40625, 0.1, 'gini = 0.236\nsamples = 22\nvalue = [19, 3]\nclass = Bad'),
#  Text(0.46875, 0.1, 'gini = 0.0\nsamples = 51\nvalue = [0, 51]\nclass = Good'),
#  Text(0.75, 0.7, 'APPLICANT_AGE <= 36.5\ngini = 0.462\nsamples = 17001\nvalue = [6158, 10843]\nclass = Good'),
#  Text(0.625, 0.5, 'AMT_INCOME_TOTAL <= 209876.0\ngini = 0.5\nsamples = 6191\nvalue = [3054, 3137]\nclass = Good'),
#  Text(0.5625, 0.3, 'AMT_INCOME_TOTAL <= 153031.5\ngini = 0.489\nsamples = 4720\nvalue = [2711, 2009]\nclass = Bad'),
#  Text(0.53125, 0.1, 'gini = 0.427\nsamples = 1665\nvalue = [514, 1151]\nclass = Good'),
#  Text(0.59375, 0.1, 'gini = 0.404\nsamples = 3055\nvalue = [2197, 858]\nclass = Bad'),
#  Text(0.6875, 0.3, 'YEARS_WORKING <= 8.5\ngini = 0.358\nsamples = 1471\nvalue = [343, 1128]\nclass = Good'),
#  Text(0.65625, 0.1, 'gini = 0.436\nsamples = 1023\nvalue = [328, 695]\nclass = Good'),
#  Text(0.71875, 0.1, 'gini = 0.065\nsamples = 448\nvalue = [15, 433]\nclass = Good'),
#  Text(0.875, 0.5, 'AMT_INCOME_TOTAL <= 158850.0\ngini = 0.409\nsamples = 10810\nvalue = [3104, 7706]\nclass = Good'),
#  Text(0.8125, 0.3, 'APPLICANT_AGE <= 53.5\ngini = 0.474\nsamples = 5433\nvalue = [2101, 3332]\nclass = Good'),
#  Text(0.78125, 0.1, 'gini = 0.49\nsamples = 4831\nvalue = [2075, 2756]\nclass = Good'),
#  Text(0.84375, 0.1, 'gini = 0.083\nsamples = 602\nvalue = [26, 576]\nclass = Good'),
#  Text(0.9375, 0.3, 'AMT_INCOME_TOTAL <= 405944.0\ngini = 0.303\nsamples = 5377\nvalue = [1003, 4374]\nclass = Good'),
#  Text(0.90625, 0.1, 'gini = 0.243\nsamples = 4760\nvalue = [673, 4087]\nclass = Good'),
#  Text(0.96875, 0.1, 'gini = 0.498\nsamples = 617\nvalue = [330, 287]\nclass = Bad')]
