# %%
import pandas as pd
csv_data = pd.read_csv("Suicide Dataset (Global Suicide Indicator).csv")

# %%
csv_data
# Out:
#                                  Country          Sex  Year  Suicide Rate  \
# 0                            Afghanistan   Both sexes  2000           8.1
# 1                            Afghanistan         Male  2000          14.3
# 2                            Afghanistan       Female  2000           1.7
# 3                                Albania   Both sexes  2000           5.8
# 4                                Albania         Male  2000           8.2
# ...                                  ...          ...   ...           ...
# 2712  Venezuela (Bolivarian Republic of)          NaN  2017           NaN
# 2713                            Viet Nam          NaN  2017           NaN
# 2714                               Yemen          NaN  2017           NaN
# 2715                              Zambia          NaN  2017           NaN
# 2716                            Zimbabwe          NaN  2017           NaN
#
#       Mental hospitals (per 100 000 population)  \
# ...

# %%
# remove NaN values
valid = csv_data[csv_data['Suicide Rate'].notna()]
# remove female and male, leaving only both sexes
valid = valid.iloc[::3, :]
# take latest year with available data
valid = valid[valid['Year'] == 2016]
# reset index and remove irrelevant columns
valid.reset_index(inplace = True)
focus = valid[['Country', 'Suicide Rate']]
focus
# Out:
#                                 Country  Suicide Rate
# 0                           Afghanistan           6.4
# 1                               Albania           5.6
# 2                               Algeria           3.3
# 3                                Angola           8.9
# 4                   Antigua and Barbuda           0.5
# ..                                  ...           ...
# 178  Venezuela (Bolivarian Republic of)           3.8
# 179                            Viet Nam           7.0
# 180                               Yemen           9.8
# 181                              Zambia          11.3
# 182                            Zimbabwe          19.1
#
# [183 rows x 2 columns]
